# %% [markdown]
# # BBox Viewer
#
# Load an image, define a bounding box as `(x, y, w, h)` in pixel units, and draw it.
# Coordinates use a top-left origin `(0, 0)` with `x` increasing to the right and `y` increasing downward.

# %%
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# --- Input / Config ---
image_path = "/home/jmadden2/Documents/Research/nicsec/data/docvqa/train/img6.jpg"
x, y, w, h = 390, 395, 40, 30

# Optional styling
edge_color = "red"
line_width = 2

img = Image.open(image_path).convert("RGB")
width, height = img.size

if w <= 0 or h <= 0:
    raise ValueError("w and h must be positive.")

fig, ax = plt.subplots(figsize=(6, 6))
ax.imshow(img)

rect = Rectangle((x, y), w, h, linewidth=line_width, edgecolor=edge_color, facecolor="none")
ax.add_patch(rect)

ax.set_xlim(0, width)
ax.set_ylim(height, 0)
ax.axis("off")
plt.show()

# %% [markdown]
# **Notes / Pitfalls**
#
# - `w` and `h` must be positive.
# - Coordinates are in pixel units.
# - If the rectangle goes outside the image, it will be clipped.

# %% [markdown]
# # Resize Images

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Replace 'your_image.jpg' with the actual path to your image file.
# For example, you can use '/content/img1.jpg'
image_path = "/home/jmadden2/Documents/Research/nicsec/data/docvqa/train/img2_edit.jpg"

# Load the image
original_image = Image.open(image_path).convert("RGB")

# Define the new size
new_size = (512, 512)

# Resize the image
resized_image = original_image.resize(new_size)

# Save the resized image back to its original filename
resized_image.save(image_path)
print(f"Resized image saved to: {image_path}")

# Display the original and resized images
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(original_image)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(resized_image)
plt.title(f'Resized Image ({new_size[0]}x{new_size[1]})')
plt.axis('off')

plt.show()

print(f"Original image size: {original_image.size}")
print(f"Resized image size: {resized_image.size}")
